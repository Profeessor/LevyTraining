# %%
zr = 0.4
szr= 0.1
#zr = zr - 0.5* np.sqrt(12)*szr + np.sqrt(12) * szr * np.random.uniform()

#zr

# %%
zr_list=[]
for i in range(1000):
    
    zr_list.append( zr - 0.5* np.sqrt(12)*szr + np.sqrt(12) * szr * np.random.uniform())

# %%
import numpy as np

# %%
np.array(zr_list).mean()
np.array(zr_list).std()
# Out:
# 0.10288877595213802

# %%
np.random.uniform()
# Out:
# 0.22986031127471418

# %%
zr_list=[]
for i in range(1000):
    
    zr_list.append( zr - 0.5* szr + szr * np.random.uniform())
np.array(zr_list).mean()
# Out:
# 0.40141119291906713

# %%
z_list=[]
for i in range(1000):
    
    z_list.append( zr - 0.5* szr + szr * np.random.uniform())
np.array(z_list).mean()
# Out:
# 0.4004892338141774

# %%
zr = 0.5
szr = 0.2
z_list=[]
for i in range(1000):
    
    z_list.append( zr - 0.5* szr + szr * np.random.uniform())
np.array(z_list).mean() 
np.array(z_list).std()
# Out:
# 0.05754150877784668

# %%
z_list=[]
for i in range(1000):
    
    z_list.append(np.random.uniform())
z_list
# Out:
# [0.26184534704819207,
#  0.7901211392732024,
#  0.4269441360719325,
#  0.10818054349614203,
#  0.5664764485866735,
#  0.6663617548590812,
#  0.4610507876882891,
#  0.5566624746186992,
#  0.21378669151010143,
#  0.8970065140229359,
#  0.8700800508790865,
#  0.713657821061266,
#  0.8164023793003415,
#  0.17990964488070216,
#  0.1749519068764661,
#  0.4962917925761866,
#  0.7782330148825121,
#  0.3572516405841729,
#  0.07653731124657259,
#  0.46022696886174697,
#  0.12958085685784437,
#  0.497229316370863,
#  0.21740969124957188,
#  0.2631758917189646,
#  0.8528008490987402,
#  0.31498326613767424,
#  0.7611464071935844,
#  0.8565178469146327,
#  0.82266792746011,
#  0.504079806082913,
#  0.9467557439734466,
#  0.2739881067616553,
#  0.6086516097629586,
#  0.3323632201736383,
#  0.9982216642514512,
#  0.05834936677655167,
#  0.21732105088555354,
#  0.3835693885685265,
#  0.7627955516510957,
#  0.05742042222830068,
#  0.5309482481218718,
#  0.9873360649052709,
#  0.6170614977651441,
# ...
